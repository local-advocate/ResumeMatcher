# %% [markdown]
# Trying to extract data from resumes

# %%
# !pip install nltk
# !pip install pyresparser
import pandas as pd
import re
import nltk
nltk.download()
# https://stackoverflow.com/questions/26693736/nltk-and-stopwords-fail-lookuperror
# need to download 'stopwords' from nltk *****************************************
# https://pypi.org/project/pyresparser/

import os
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# !ls '/content/gdrive/Shareddrives/CSE 144 DATA/DATA'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> stopwords
# ...
#       Unzipping corpora/stopwords.zip.
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> stopwords
# Command 'stopwords' unrecognized
#
# ---------------------------------------------------------------------------
# ...

# %%
# https://www.kaggle.com/datasets/gauravduttakiit/resume-dataset
resumes_df = pd.read_csv('/content/gdrive/Shareddrives/CSE 144 DATA/DATA/gauravduttakiit_resume-dataset.csv' ,encoding='utf-8')

# Adding 'Cleaned_Reume' column
#dataset_1['Cleaned_Resume'] = ''
resumes_df.head()
# Out:
#        Category                                             Resume
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# 3  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4  Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...

# %%
from pyresparser import ResumeParser


# Read the resumes into a Pandas DataFrame
#resumes_df = pd.read_csv('resumes.csv')  # Replace with the path to your resume file or adjust the read_csv parameters accordingly

# Initialize the ResumeParser
resume_parser = ResumeParser()

# Initialize empty lists to store extracted information
resume_descriptions = []
skills_lists = []
education_lists = []
experience_lists = []

# Iterate over each resume
for index, row in resumes_df.iterrows():
    resume_text = row['resume_text']  # Replace with the column name that contains the resume text in your DataFrame
    
    # Create a temporary file and write the resume text into it
    with tempfile.NamedTemporaryFile(mode='w', delete=False) as temp_file:
        temp_file.write(resume_text)
        temp_file.seek(0)
        resume_file_path = temp_file.name
    
        # Parse the resume file
        data = resume_parser.parse(resume_file_path)

    # Extract information
    resume_description = data['resume']
    skills = data['skills']
    education = data['education']
    experience = data['experience']
    
    # Append the extracted information to the respective lists
    resume_descriptions.append(resume_description)
    skills_lists.append(skills)
    education_lists.append(education)
    experience_lists.append(experience)

    # Delete the temporary file
    temp_file.close()
    if temp_file.name:
        os.remove(temp_file.name)

# Add the extracted information back to the DataFrame
resumes_df['resume_description'] = resume_descriptions
resumes_df['skills'] = skills_lists
resumes_df['education'] = education_lists
resumes_df['experience'] = experience_lists

# Save the DataFrame with the extracted information to a new CSV file
resumes_df.to_csv('resumes_with_extraction.csv', index=False)  # Replace with the desired file path and name
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-21673dbd76db> in <cell line: 8>()
#       6
#       7 # Initialize the ResumeParser
# ----> 8 resume_parser = ResumeParser()
#       9
#      10 # Initialize empty lists to store extracted information
#
# TypeError: ResumeParser.__init__() missing 1 required positional argument: 'resume'
