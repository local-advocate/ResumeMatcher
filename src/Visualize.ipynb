# %%
import pandas as pd
import re
import nltk
import os
from google.colab import drive

# %%
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
INPUT_FOLDER = '/content/gdrive/Shareddrives/CSE 144 DATA/DATA'

# %%
# Read the Datasets
jobs_ds = pd.read_csv(INPUT_FOLDER + '/Final Job Dataset.csv', encoding='utf-8')
resume_ds = pd.read_csv(INPUT_FOLDER + '/Clean Resume Guara.csv', encoding='utf-8')

# %%
resume_ds.head(1)
# Out:
#    Unnamed: 0      Category                                             Resume
# 0           0  Data Science  Skills Programming Languages Python pandas num...

# %%
jobs_ds.shape
# Out:
# (52002, 10)

# %%
import matplotlib.pyplot as plt

# %%
state_counts = jobs_ds['State'].value_counts()
print(state_counts)
# Out:
# CA            6116
# TX            5514
# OH            3315
# NY            2719
# FL            2381
#               ...
# Nevada           1
# Sydney NSW       1
# Oklahoma         1
# Home Based       1
# GU               1
# Name: State, Length: 83, dtype: int64

# %%
state_data = pd.DataFrame({'State': state_counts.index, 'count': state_counts.values})
state_data.to_csv('jobs_offer_by_state.csv',index=False)

# %%
catg_count = resume_ds['Category'].value_counts()
print(catg_count)
# Out:
# Java Developer               84
# Testing                      70
# DevOps Engineer              55
# Python Developer             48
# Web Designing                45
# HR                           44
# Hadoop                       42
# Blockchain                   40
# ETL Developer                40
# Operations Manager           40
# Data Science                 40
# Sales                        40
# Mechanical Engineer          40
# Arts                         36
# Database                     33
# Electrical Engineering       30
# Health and fitness           30
# PMO                          30
# Business Analyst             28
# DotNet Developer             28
# Automation Testing           26
# Network Security Engineer    25
# SAP Developer                24
# Civil Engineer               24
# Advocate                     20
# Name: Category, dtype: int64

# %%
resume_data = pd.DataFrame({'Title': catg_count.index, 'count': catg_count.values})
resume_data.to_csv('catg_count.csv',index=False)

# %%
tmp = pd.read_csv(INPUT_FOLDER + '/gauravduttakiit_resume-dataset.csv', encoding='utf-8')
tmp2 = pd.read_csv(INPUT_FOLDER + '/snehaanbhawal_resume-dataset.csv', encoding='utf-8')

# %%
tmp.shape
# Out:
# (962, 2)

# %%
tmp2.shape
# Out:
# (2484, 4)

# %%
tmp.head(1)
# Out:
#        Category                                             Resume
# 0  Data Science  Skills * Programming Languages: Python (pandas...

# %%
tmp2.head(1)
# Out:
#          ID                                         Resume_str  \
# 0  16852973           HR ADMINISTRATOR/MARKETING ASSOCIATE\...
#
#                                          Resume_html Category
# 0  <div class="fontsize fontface vmargins hmargin...       HR

# %%
tmp3 = pd.read_csv(INPUT_FOLDER + '/Job Descriptions Dataset 1.csv', encoding='utf-8')
tmp4 = pd.read_csv(INPUT_FOLDER + '/Job Descriptions Dataset 2.csv', encoding='utf-8')

# %%
tmp3.shape
# Out:
# (30002, 30)

# %%
tmp4.shape
# Out:
# (22000, 14)

# %%
tmp3.head()
# Out:
#                        Job Title  \
# 0                  Shift Manager
# 1     Operations Support Manager
# 2  Senior Product Manager - Data
# 3     Part-Time Office Concierge
# 4    Print & Marketing Associate
#
#                                      Job Description  Job Type  Categories  \
# 0  <div id="jobDescriptionText" class="jobsearch-...       NaN         NaN
# 1  <div id="jobDescriptionText" class="jobsearch-...       NaN         NaN
# 2  <div id="jobDescriptionText" class="jobsearch-...       NaN         NaN
# 3  <div id="jobDescriptionText" class="jobsearch-...       NaN         NaN
# 4  <div id="jobDescriptionText" class="jobsearch-...       NaN         NaN
#
#                   Location           City State        Country Zip Code  \
# 0  Mission Hills, CA 91345  Mission Hills    CA  United States    91345
# 1        Atlanta, GA 30342        Atlanta    GA  United States    30342
# 2              Chicago, IL        Chicago    IL  United States      NaN
# ...
